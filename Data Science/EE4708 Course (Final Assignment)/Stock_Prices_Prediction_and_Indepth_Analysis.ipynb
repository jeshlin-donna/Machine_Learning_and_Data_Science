# %% [markdown]
# #**Stock Prices Prediction and Analysis**

# %%
#importing the basic required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ###Reading data from the given data format(excel file)

# %%
from google.colab import files 
uploaded= files.upload() #uploading the files
# Out:
#      <input type="file" id="files-4da7cc1d-7b5a-4d14-9852-ae80a464a3df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4da7cc1d-7b5a-4d14-9852-ae80a464a3df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Cognizant share prices 2019_2021.xls to Cognizant share prices 2019_2021.xls
# Saving HCL Technologies share prices 2019_2021.xls to HCL Technologies share prices 2019_2021.xls
# Saving HDFC Bank Share Prices 2019_2021.xls to HDFC Bank Share Prices 2019_2021.xls
# Saving ICICI Bank Share Prices 2019_2021.xls to ICICI Bank Share Prices 2019_2021.xls
# Saving Infosys Share Prices 2019_2021.xls to Infosys Share Prices 2019_2021.xls
# Saving SBI Share Prices 2019_2021.xls to SBI Share Prices 2019_2021.xls
# ...

# %%
import io

#creating dataframes from the excel files
cognizant_df=pd.read_excel(io.BytesIO(uploaded['Cognizant share prices 2019_2021.xls'])) 
hcl_df=pd.read_excel(io.BytesIO(uploaded['HCL Technologies share prices 2019_2021.xls'])) 
hdfc_df=pd.read_excel(io.BytesIO(uploaded['HDFC Bank Share Prices 2019_2021.xls'])) 
icici_df=pd.read_excel(io.BytesIO(uploaded['ICICI Bank Share Prices 2019_2021.xls'])) 
infosys_df=pd.read_excel(io.BytesIO(uploaded['Infosys Share Prices 2019_2021.xls'])) 
sbi_df=pd.read_excel(io.BytesIO(uploaded['SBI Share Prices 2019_2021.xls'])) 

US_INR_exchange_df=pd.read_excel(io.BytesIO(uploaded['USD-INR Exchange rate 2019_2021.xls']))

# %%
dfs= [cognizant_df, hcl_df, hdfc_df, icici_df, infosys_df, sbi_df, US_INR_exchange_df]
stock_and_exchange_types= ['cognizant', 'hcl', 'hdfc', 'icici', 'infosys', 'sbi', 'US_INR_exchange']

# %% [markdown]
# ###Creating a new variable called "return"

# %% [markdown]
# The "return" on a stock on a particular period is defined as the change in price of an asset, investment, or project over that period of time, which may be represented in terms of price change or percentage change.
#
# **And is given by the formulae:**
#
# ![image.png](data:image/png;base64,...)

# %%
#Creating a new variable called "return"
for df in dfs:
  df['Return']=(df['Close']-df['Open'])/df['Open']

# %% [markdown]
# ###Merging all the dataframes

# %%
cognizant_df =        cognizant_df.rename(columns= {'Open': 'cognizant'+' open', 'Close': 'cognizant'+' close', 'High':'cognizant'+' high','Low': 'cognizant'+' low','Return': 'cognizant'+' return','Volume': 'cognizant'+' volume'})
sbi_df =              sbi_df.rename(columns= {'Open': 'sbi'+' open', 'Close': 'sbi'+' close', 'High':'sbi'+' high','Low': 'sbi'+' low','Return': 'sbi'+' return','Volume': 'sbi'+' volume'})
hdfc_df =             hdfc_df.rename(columns= {'Open': 'hdfc'+' open', 'Close': 'hdfc'+' close', 'High':'hdfc'+' high','Low': 'hdfc'+' low','Return': 'hdfc'+' return','Volume': 'hdfc'+' volume'})
icici_df =            icici_df.rename(columns= {'Open': 'icici'+' open', 'Close': 'icici'+' close', 'High':'icici'+' high','Low': 'icici'+' low','Return': 'icici'+' return','Volume': 'icici'+' volume'})
infosys_df =          infosys_df.rename(columns= {'Open': 'infosys'+' open', 'Close': 'infosys'+' close', 'High':'infosys'+' high','Low': 'infosys'+' low','Return': 'infosys'+' return','Volume': 'infosys'+' volume'})
hcl_df =              hcl_df.rename(columns= {'Open': 'hcl'+' open', 'Close': 'hcl'+' close', 'High':'hcl'+' high','Low': 'hcl'+' low','Return': 'hcl'+' return','Volume': 'hcl'+' volume'})
US_INR_exchange_df =  US_INR_exchange_df.rename(columns= {'Open': 'US_INR_exchange'+' open', 'Close': 'US_INR_exchange'+' close', 'High':'US_INR_exchange'+' high','Low': 'US_INR_exchange'+' low','Return': 'US_INR_exchange'+' return','Volume': 'US_INR_exchanget'+' volume'})

# %%
common_df=cognizant_df.merge(hcl_df, on="Date")
common_df=common_df.merge(hdfc_df, on="Date")
common_df=common_df.merge(icici_df, on="Date")
common_df=common_df.merge(infosys_df, on="Date")
common_df=common_df.merge(sbi_df, on="Date")
common_df=common_df.merge(US_INR_exchange_df, on="Date")

# %%
common_df.head()
# Out:
#         Date  cognizant open  ...  Adj Close  US_INR_exchange return
# 0 2020-10-05       69.620003  ...  73.322403               -0.000001
# 1 2020-10-06       70.900002  ...  73.108299               -0.000103
# 2 2020-10-07       70.730003  ...  73.815002                0.000000
# 3 2020-10-08       72.500000  ...  73.542503                0.000000
# 4 2020-10-09       73.650002  ...  73.280502                0.000000
#
# [5 rows x 43 columns]

# %%
common_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 0 to 239
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    240 non-null    datetime64[ns]
#  1   cognizant open          240 non-null    float64
#  2   cognizant high          240 non-null    float64
#  3   cognizant low           240 non-null    float64
#  4   cognizant close         240 non-null    float64
#  5   cognizant volume        240 non-null    int64
#  6   cognizant return        240 non-null    float64
#  7   hcl open                240 non-null    float64
#  8   hcl high                240 non-null    float64
#  9   hcl low                 240 non-null    float64
#  10  hcl close               240 non-null    float64
#  11  hcl volume              240 non-null    float64
#  12  hcl return              240 non-null    float64
#  13  hdfc open               240 non-null    float64
# ...

# %%
# Creating a Dataframe containing the returns of every stock/exchange type
returns = common_df[['Date','cognizant return','hcl return','hdfc return','icici return','infosys return','sbi return','US_INR_exchange return']]

returns.head()
# Out:
#         Date  cognizant return  ...  sbi return  US_INR_exchange return
# 0 2020-10-05          0.018816  ...   -0.016927               -0.000001
# 1 2020-10-06         -0.015092  ...    0.002616               -0.000103
# 2 2020-10-07          0.021349  ...   -0.009608                0.000000
# 3 2020-10-08          0.005655  ...    0.000784                0.000000
# 4 2020-10-09         -0.007739  ...    0.032813                0.000000
#
# [5 rows x 8 columns]

# %% [markdown]
# ##**Exploratory Data Analysis**

# %%
# Importing the basic libraries required for visualizations
import os
import torch
import torchvision
import tarfile
from torch.utils.data import random_split
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Create a pairplot using seaborn of the returns dataframe

import seaborn as sns
plt.figure(figsize=(0.2,0.2))
sns.pairplot(returns[1:])

# %% [markdown]
# **INSIGHT:**
# The pairplots show that
# * The returns of HCL and Infosys show a very mild linearity. (Both these companies belong to the IT and Consulting sectors)
# * The returns of ICICI, HDFC and SBI show a very mild linearity. (This is due to the basic reason that all of these three companies are from the same banking sector)

# %% [markdown]
# ####**On what dates did each kind of stock/exchange have the best and worst single day returns?**

# %%
#worst single day returns

for i in ['cognizant return', 'hcl return', 'hdfc return', 'icici return', 'infosys return', 'sbi return', 'US_INR_exchange return']:
  min_return=min(returns[i])
  for j in range(0,len(returns)):
    if returns[i][j]==min_return:
       date=returns['Date'][j]
       print(i,'  ',min_return,'  ',date)
# Out:
# cognizant return    -0.05091547371601019    2020-10-29 00:00:00
# hcl return    -0.0552188561778719    2021-01-15 00:00:00
# hdfc return    -0.0397820326975477    2021-01-27 00:00:00
# icici return    -0.03907592586496817    2020-10-15 00:00:00
# infosys return    -0.06080508474576271    2020-10-15 00:00:00
# sbi return    -0.05122002006094162    2020-12-21 00:00:00
# US_INR_exchange return    -0.00385194613378757    2021-01-08 00:00:00

# %% [markdown]
# **INFERANCE:**
# * Both ICICI and Infosys had their worst returns on "2020-10-15". **Since 2 of the companies share the same day for the worst drop, did anything significant happen that day?** ('https://www.livemint.com/market/stock-market-news/sensex-nifty-live-today-15-10-2020-nifty-nse-bse-news-updates-11602729631205.html') Benchmark indices tumbled on global meltdown. Sensex plunged 1066 points to end at 39,728 and Nifty slipped 2.5% to 11,680. Investors lost ₹3,33,360.15 crore in trade on that day. Market players booked profit amid fears of a second wave of virus, as large European cities ordered clampdowns. On the Nifty, only three stocks advanced and 47 declined. The volatility index VIX rose 9% as the market breadth remained weak. "All sectoral indices ended in the red with banks and IT clocking the biggest loss".

# %%
#best single day returns
for i in ['cognizant return', 'hcl return', 'hdfc return', 'icici return', 'infosys return', 'sbi return', 'US_INR_exchange return']:
  max_return=max(returns[i])
  for j in range(0,len(returns)):
    if returns[i][j]==max_return:
       date=returns['Date'][j]
       print(i,'  ',max_return,'  ',date)
# Out:
# cognizant return    0.03494472279158233    2021-02-24 00:00:00
# hcl return    0.047079556898288015    2021-07-15 00:00:00
# hdfc return    0.05237468129708487    2021-02-24 00:00:00
# icici return    0.09384055797101447    2021-02-01 00:00:00
# infosys return    0.03257191201353638    2020-12-22 00:00:00
# sbi return    0.0897930742239269    2021-02-01 00:00:00
# US_INR_exchange return    0.003574004586497    2020-12-23 00:00:00

# %% [markdown]
# **INFERANCE:**
# * Cognizant and HDFC had their best returns on "2021-02-24". **Since 2 of the companies share the same day for the highest gain, did anything significant happen that day?** ('https://www.nasdaq.com/articles/stock-market-news-for-feb-24-2021-2021-02-24') Markets Bounce Back After Federal Reserve Chair Eases Concerns.
# * ICICI and SBI had their best returns on "2021-02-01" **Since 2 of the banks share the same day for the highest gain, did anything significant happen that day?**('https://www.businesstoday.in/news/story/union-budget-2021-after-idfc-icici-and-idbi-conversion-into-banks-govt-proposes-new-dfi-286177-2021-02-01') Insurance to be the game-changer with no 74% FDI, lower bad debt eases stress on banks.

# %% [markdown]
# **INFERANCE:**
# * **Infosys's largest drop(2020-10-15) and biggest gain(2020-12-22) were considerably close to one another, did anything significant happen in that time frame?**
#   An Interim dividend of 240% was announced on 2020-10-14. After a stock goes ex-dividend, the share price typically drops by the amount of the dividend paid to reflect the fact that new shareholders are not entitled to that payment. Dividends paid out as stock instead of cash can dilute earnings, which can also have a negative impact on share prices in the short term. The reason for this price drop is because the amount paid out no longer belongs to the company.

# %%
for i in ['cognizant return', 'hcl return', 'hdfc return', 'icici return',
       'infosys return', 'sbi return', 'US_INR_exchange return']:
    print(i,returns[i].std())
# Out:
# cognizant return 0.011227685656946169
# hcl return 0.016341285406363426
# hdfc return 0.014748900272528393
# icici return 0.016901830143954723
# infosys return 0.012745030351792768
# sbi return 0.01992815454624904
# US_INR_exchange return 0.0009053790709182797

# %% [markdown]
# **INFERANCE:**
# * **Taking a look at the standard deviation of the returns, the stocks of SBI Bank would be classified as the riskiest over the entire time period.**
# * **Taking a look at the standard deviation of the returns, the stocks of Cognizant would be classified as the safest over the entire time period.**

# %%
sns.distplot(returns['sbi return'],color='red',bins=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(returns['cognizant return'],color='blue',bins=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for stock_and_exchange_type in stock_and_exchange_types:
    common_df[stock_and_exchange_type+' close'].plot(figsize=(12,4),label=stock_and_exchange_type)
plt.legend()

# %% [markdown]
# ###Moving Averages
# Let's analyze the moving averages for these stocks in the given years.

# %%
plt.figure(figsize=(12,6))

common_df['hdfc close'].rolling(window=30).mean().plot(label='30 Day Avg (HDFC)')
common_df['hdfc close'].plot(label='HDFC close')
common_df['sbi close'].rolling(window=30).mean().plot(label='30 Day Avg (SBI)')
common_df['sbi close'].plot(label='SBI close')
common_df['icici close'].rolling(window=30).mean().plot(label='30 Day Avg (ICICI)')
common_df['icici close'].plot(label='ICICI close')
common_df['infosys close'].rolling(window=30).mean().plot(label='30 Day Avg (Infosys)')
common_df['infosys close'].plot(label='Infosys close')
common_df['hcl close'].rolling(window=30).mean().plot(label='30 Day Avg (HCL)')
common_df['hcl close'].plot(label='HCL close')
common_df['cognizant close'].rolling(window=30).mean().plot(label='30 Day Avg (Cognizant)')
common_df['cognizant close'].plot(label='Cognizant close')
common_df['US_INR_exchange close'].rolling(window=30).mean().plot(label='30 Day Avg (US_INR_exchange)')
common_df['US_INR_exchange close'].plot(label='US_INR_exchange close')

plt.legend()

# %% [markdown]
# ###Seaborn heatmap of the correlation between the Stocks Close Price

# %%
correlation_matrix = common_df[['cognizant return', 'hcl return', 'hdfc return', 'icici return', 'infosys return', 'sbi return', 'US_INR_exchange return']].corr()
sns.heatmap(correlation_matrix, annot=True)

# %% [markdown]
# ###Seaborn's clustermap (To cluster the correlations together)

# %%
sns.clustermap(correlation_matrix, annot=True)

# %% [markdown]
# ##**Predicting Stock Prices (for HDFC Bank)**
#
# Stock market prediction and analysis are some of the most difficult jobs to complete. There are numerous causes for this, including market volatility and a variety of other dependent and independent variables that influence the value of a certain stock in the market. These variables make it extremely difficult for any stock market expert to anticipate the rise and fall of the market with great precision.
#
# However, with the introduction of Machine Learning and its strong algorithms, the most recent market research and Stock Market Prediction advancements have begun to include such approaches in analyzing stock market data.

# %%
#Importing the Libraries
import pandas as PD
import numpy as np
# %matplotlib inline
import matplotlib. pyplot as plt
import matplotlib
from sklearn.preprocessing import MinMaxScaler
from keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib. dates as mandates
from sklearn.preprocessing import MinMaxScaler
from sklearn import linear_model
from keras. models import Sequential
from keras. layers import Dense
import keras. backend as K
from keras. callbacks import EarlyStopping
from keras. models import load_model
from keras. layers import LSTM
from keras. utils.vis_utils import plot_model

# %%
df=common_df

# %%
#Set Target Variable
output_var = PD.DataFrame(df['hdfc close'])
#Selecting the Features
features = ['hdfc open', 'hdfc high', 'hdfc low', 'hdfc volume']

# %%
#Scaling
scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(df[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform, index=df.index)

feature_transform.head()
# Out:
#    hdfc open  hdfc high  hdfc low  hdfc volume
# 0   0.000000   0.000000  0.000000     0.295703
# 1   0.044327   0.031434  0.030556     0.356802
# 2   0.063269   0.064538  0.053473     0.403956
# 3   0.130769   0.139489  0.105237     0.750973
# 4   0.171154   0.206287  0.162127     1.000000

# %%
#Splitting to Training set and Test set
timesplit= TimeSeriesSplit(n_splits=10)
for train_index, test_index in timesplit.split(feature_transform):
        X_train, X_test = feature_transform[:len(train_index)], feature_transform[len(train_index): (len(train_index)+len(test_index))]
        y_train, y_test = output_var[:len(train_index)].values.ravel(), output_var[len(train_index): (len(train_index)+len(test_index))].values.ravel()

# %%
#Process the data for LSTM
trainX =np.array(X_train)
testX =np.array(X_test)
X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = testX.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
#Building the LSTM Model
lstm = Sequential()
lstm.add(LSTM(32, input_shape=(1, trainX.shape[1]), activation='relu', return_sequences=False))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error', optimizer='adam')

# %%
#Model Training
history=lstm.fit(X_train, y_train, epochs=15000, batch_size=8, verbose=1, shuffle=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# 28/28 [==============================] - 0s 5ms/step - loss: 49.5099
# Epoch 12502/15000
# 28/28 [==============================] - 0s 4ms/step - loss: 49.5102
# Epoch 12503/15000
# 28/28 [==============================] - 0s 5ms/step - loss: 49.5099
# Epoch 12504/15000
# 28/28 [==============================] - 0s 4ms/step - loss: 49.5101
# Epoch 12505/15000
# 28/28 [==============================] - 0s 4ms/step - loss: 49.5097
# Epoch 12506/15000
# 28/28 [==============================] - 0s 4ms/step - loss: 49.5101
# Epoch 12507/15000
# 28/28 [==============================] - 0s 4ms/step - loss: 49.5098
# Epoch 12508/15000
# 28/28 [==============================] - 0s 4ms/step - loss: 49.5100
# Epoch 12509/15000
# 28/28 [==============================] - 0s 4ms/step - loss: 49.5097
# Epoch 12510/15000
# 28/28 [==============================] - 0s 4ms/step - loss: 49.5100
# Epoch 12511/15000
# ...

# %%
#LSTM Prediction
y_pred= lstm.predict(X_test)

# %%
#Predicted vs True Close Value – LSTM

plt.plot(y_test, label='True Value')
plt.plot(y_pred, label='LSTM Value')
plt.title('Prediction by LSTM')
plt.xlabel('Time Scale')
plt.ylabel('Stock Close')
plt.legend()
plt.show()

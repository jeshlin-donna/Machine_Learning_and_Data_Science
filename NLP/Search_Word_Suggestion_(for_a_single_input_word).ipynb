# %% [markdown]
# # **Create The Vocabulary**

# %%
''''import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk import word_tokenize
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from bs4 import BeautifulSoup
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences''''
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
''''from google.colab import drive
drive.mount('/content/drive')''''
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#df=pd.read_csv('/content/drive/MyDrive/GoGlocal/imp-code.csv')

# %%
''''REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwords from text
    return text''''

# %%
''''def apply_basic_preprocessing(df):
 df['preprocessed_Description'] = df['Description'].str.lower() #reduces all letters in the comments to lower case
 df['preprocessed_Description'].replace( { r'[^a-zA-Z ]' : ' ' }, inplace= True, regex = True) #anything other than (a-z)(A-Z)(space) will be removed
                                                                                 # ^ means "not" in regex
    
 df['preprocessed_Description'] = df['preprocessed_Description'].apply(clean_text)
 return(df)''''

# %%
''''def drop_null_preprocessed_descriptions(df):
  df = df[df.preprocessed_Description!='']
  return(df)''''

# %%
''''def apply_all_preprocessing(df):
  df= apply_basic_preprocessing(df)
  df= drop_null_preprocessed_descriptions(df)
  return(df)''''

# %%
df= apply_all_preprocessing(df)

# %%
''''def create_and_fit_tokenizer(df):
 # create the dict.
 tokenizer = Tokenizer()
 tokenizer.fit_on_texts(df['preprocessed_Description'].values)
  
 # number of unique words in dict.
 print("Number of unique words in dictionary=", 
      len(tokenizer.word_index))
 print("Dictionary is = ", tokenizer.word_index)
 return(tokenizer)''''

# %%
#tokenizer=create_and_fit_tokenizer(df)
# Out:
# Number of unique words in dictionary= 24567
# ...

# %%
#def create_dictionary(fitted_tokenizer):
# dictionary = tokenizer.word_index
# return(dictionary)

# %%
#dictionary= create_dictionary(tokenizer)
#dictionary
# Out:
# {'nesoi': 1,
#  'mm': 2,
#  'gt': 3,
#  'fibers': 4,
#  'g': 5,
#  'w': 6,
#  'lt': 7,
#  'cotton': 8,
#  'knitted': 9,
#  'nt': 10,
#  'percent': 11,
#  'etc': 12,
#  'less': 13,
#  'containing': 14,
#  'parts': 15,
#  'except': 16,
#  'wool': 17,
#  'weight': 18,
#  'steel': 19,
#  'made': 20,
#  'exceeding': 21,
#  'textile': 22,
#  'oth': 23,
#  'n': 24,
#  'note': 25,
#  'silk': 26,
#  'iron': 27,
#  'crocheted': 28,
#  'fresh': 29,
#  'greater': 30,
#  'man': 31,
#  'cm': 32,
#  'exc': 33,
#  'metal': 34,
#  'equal': 35,
#  'similar': 36,
#  'girls': 37,
#  'ov': 38,
#  'materials': 39,
#  'articles': 40,
#  'fab': 41,
#  'used': 42,
#  'fabrics': 43,
#  'cot': 44,
#  'synthetic': 45,
#  'boys': 46,
#  'frozen': 47,
#  'fabric': 48,
#  'machines': 49,
#  'kg': 50,
#  'animal': 51,
#  'wov': 52,
#  'weighing': 53,
#  'hair': 54,
#  'woven': 55,
#  'whether': 56,
#  'including': 57,
#  'b': 58,
#  'rubber': 59,
#  'knit': 60,
#  'type': 61,
#  'mixed': 62,
#  'wood': 63,
# ...

# %%
#dictionary.keys()
# Out:
# dict_keys(['nesoi', 'mm', 'gt', 'fibers', 'g', 'w', 'lt', 'cotton', 'knitted', 'nt', 'percent', 'etc', 'less', 'containing', 'parts', 'except', 'wool', 'weight', 'steel', 'made', 'exceeding', 'textile', 'oth', 'n', 'note', 'silk', 'iron', 'crocheted', 'fresh', 'greater', 'man', 'cm', 'exc', 'metal', 'equal', 'similar', 'girls', 'ov', 'materials', 'articles', 'fab', 'used', 'fabrics', 'cot', 'synthetic', 'boys', 'frozen', 'fabric', 'machines', 'kg', 'animal', 'wov', 'weighing', 'hair', 'woven', 'whether', 'including', 'b', 'rubber', 'knit', 'type', 'mixed', 'wood', 'fine', 'rolled', 'use', 'syn', 'heading', 'prepared', 'outer', 'dried', 'staple', 'waste', 'fr', 'fillets', 'oil', 'paper', 'base', 'trousers', 'u', 'artificial', 'chilled', 'fb', 'fib', 'acid', 'leather', 'ftwr', 'valued', 'sheets', 'accessories', 'non', 'stl', 'retail', 'ex', 'plastics', 'cont', 'wgt', 'described', 'tex', 'products', 'coated', 'width', 'containers', 'footwear', 'ot', 'uppers', 'soles', 'tobacco', 'weave'
# ...

# %%
#f= open("/content/drive/MyDrive/GoGlocal/all_words.txt","w+")

# %%
# for key in dictionary.keys():
#     f.write(key+'\n')

# %%
# f.close()

# %% [markdown]
# # **Output the word suggestions**

# %%
# !pip3 install pyenchant
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import sys

# %%
# !sudo apt-get install python-enchant
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-enchant is already the newest version (2.0.0-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
import enchant

# %%
#load the personal word list dictionary
HScode_dict = enchant.pypwl.PyPWL('all_words.txt')

# %%
def get_suggestion(input_word):
  
 #check if the word exists in the dictionary
 word_exists = HScode_dict.check(input_word)

 if word_exists:
   print("word exists: ", word_exists)
   return(None)

 if not word_exists:
    #get suggestions for the input word
    suggestions = HScode_dict.suggest(input_word)
    print ("input word:", input_word)
    print("suggestions:", suggestions)
    return(suggestions)

# %%
get_suggestion('ensamble')
# Out:
# input word: ensamble
# suggestions: ['ensmbls', 'ensembles', 'enamld', 'enameled', 'enamels', 'examle', 'example', 'etcsable', 'erasable', 'sable']
# ['ensmbls',
#  'ensembles',
#  'enamld',
#  'enameled',
#  'enamels',
#  'examle',
#  'example',
#  'etcsable',
#  'erasable',
#  'sable']
